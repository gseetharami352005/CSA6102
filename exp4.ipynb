# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetharami352005/CSA6102/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

def dns_lookup(domain):
    try:
        ip_address = socket.gethostbyname(domain)
        print("=== DNS Lookup Result ===")
        print(f"Domain Name : {domain}")
        print(f"IP Address  : {ip_address}")
    except socket.gaierror:
        print("Error: Unable to resolve the domain name.")

# Main Program
domain = input("Enter the domain name (e.g., example.com): ")
dns_lookup(domain)
# Out:
# Enter the domain name (e.g., example.com): hotstar.com
# === DNS Lookup Result ===
# Domain Name : hotstar.com
# IP Address  : 54.230.70.79
